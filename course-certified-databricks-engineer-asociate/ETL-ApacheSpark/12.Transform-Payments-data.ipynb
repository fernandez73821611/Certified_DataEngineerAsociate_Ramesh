-- %% [markdown]
-- # Transform Payments data

-- %% [markdown]
-- ## Estas transformaciones que veremos esn este noteboocks suelen venir para el examen DEA

-- %% [markdown]
-- ### Como trabajar con Marcas de Tiempo y extraer parte de la marca de tiempo

-- %% [markdown]
-- Lo que haremos es dividir la columand payment_timestamp en dos columnas una de fecha y la otra de hora de pago

-- %%
SELECT *FROM gizmobox.bronze.payments;

-- %%
SELECT date_format('2026-02-13','y-MM-d')

-- %%
SELECT date_format('18:24:45','h:mm:ss')

-- %%
-- DATABRICKS OFRECE UNA FUNCION LLAMADA  FORMATO DE FECHA
SELECT 
payment_id,
order_id,
cast(date_format(payment_timestamp,'yyyy-MM-dd')as DATE)  as payment_date,
date_format(payment_timestamp,'HH:mm:ss') as payment_time,
payment_status,
payment_method
FROM gizmobox.bronze.payments;

-- %% [markdown]
-- ### la columna de estado de pago en ves de estar conformado por numero lo vamos a categorizar como exito, pendiente ,cancelado y fallido

-- %%
CASE

-- %%
SELECT 
payment_id,
order_id,
cast(date_format(payment_timestamp,'yyyy-MM-dd')as DATE)  as payment_date,
date_format(payment_timestamp,'HH:mm:ss') as payment_time,
CASE payment_status
  when 1 then 'Sucess'
  when 2 then 'Pending'
  when 3 then 'Cancelled' 
  when 4 then 'Failed'
  end as payment_status,
payment_method
FROM gizmobox.bronze.payments;

-- %% [markdown]
-- ### Write o escribir en una tabla managed o delta en la capa silver

-- %%
CREATE TABLE IF NOT EXISTS gizmobox.silver.payments
AS
SELECT 
payment_id,
order_id,
cast(date_format(payment_timestamp,'yyyy-MM-dd')as DATE)  as payment_date,
date_format(payment_timestamp,'HH:mm:ss') as payment_time,
CASE payment_status
  when 1 then 'Sucess'
  when 2 then 'Pending'
  when 3 then 'Cancelled' 
  when 4 then 'Failed'
  end as payment_status,
payment_method
FROM gizmobox.bronze.payments;

-- %%
SELECT *FROM gizmobox.silver.payments;
