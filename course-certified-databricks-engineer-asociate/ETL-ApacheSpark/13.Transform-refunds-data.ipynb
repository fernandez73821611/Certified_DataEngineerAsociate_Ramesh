-- %% [markdown]
-- ### Esta session tambien viene en el examen asi que tenernlo en cuenta

-- %% [markdown]
-- ### Split funtion: <En esta oportunidad para dividir una columna

-- %%
SELECT split('Joseph:Fernandez', ':')

-- %%
SELECT 
split(refund_reason, ':')[0]  as refund_reason
split(refund_reason, ':')[1]  as refund_source
FROM hive_metastore.bronze.refunds;

-- %% [markdown]
-- ### Regexp_extract funtion: Para extraer y dividir en columans el string

-- %% [markdown]
-- tu tienes una tabla externa que hace referencia a los reembolsos de la tabla de la base de datos de azure sql database para hacer esto tiene sque el jdbc parar el jdbc, user, passord entre otros, perfecto pero que pasa si una ves transormado en la capa bronze quiero pasarlo a la capa silver , creo la capa silver sin un storage location, y creo una tabla gestionada o delta dentro de hive_metastore , donde se gurada esta tabla puede ser una pregunta de exmen: se guar dan la ruta **dbfs:/user/hive/warehouse/silver.db/refunds**
