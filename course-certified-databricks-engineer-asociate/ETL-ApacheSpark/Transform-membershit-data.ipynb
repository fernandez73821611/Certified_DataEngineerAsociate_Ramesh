-- %% [markdown]
-- # Transform menbershit data]

-- %% [markdown]
-- ### Extraer el customer_id de la ruta de archivo

-- %%
SELECT *FROM gizmobox.bronze.v_membershit;

-- %% [markdown]
-- ### utlizamos las expresiones regulares para tomar el id de la ruta de archivo

-- %%
SELECT 
regexp_extract(path,'.*/(.*)')
FROM 
gizmobox.bronze.v_membershit;

-- %%
SELECT regexp_extract('Joseph_1234', '(\\d+)', 1) as result
