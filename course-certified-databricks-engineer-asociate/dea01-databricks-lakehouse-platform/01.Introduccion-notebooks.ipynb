# %% [markdown]
# # Introduccion a Notebocks
# ## Databricks Lakeflow
# Este curso es completo que te ayudara a certificarte a DEA y te ayudara con proyectos reales
# - Spark SQL
# > Python and SQL

# %%
print("Bienvenido al curso de CERTIFID DATABRICKS DATA ENGINEER ASSOCIATE")

# %%
# %sql
SELECT('Bienvenido al curso de Databricks') as `Bienvenido compañero`
