# %% [markdown]
# # Comandos Mágicos de Databricks
# - **%python, %scala, %sql, %r:** Cambia a un lenguaje diferente para una celda específica.
#
# - **%md:** Markdown para documentar notebooks.
#
# - **%fs:** Ejecuta comandos del sistema de archivos (File System).
#
# - **%sh:** Ejecuta comandos de shell (solo en el Nodo Driver).
#
# - **%pip:** Instala librerías de Python.
#
# - **%run:** Incluye o importa otro notebook dentro del notebook actual

# %% [markdown]
# **%fs:** Ejecuta comandos del sistema de archivos (File System).

# %%
# %fs ls

# %%
# %fs ls dbfs:/databricks-datasets/

# %% [markdown]
# **%sh:** Ejecuta comandos de shell (solo en el Nodo Driver).

# %%
# %sh pwd

# %%
# %sh ps

# %% [markdown]
# **%pip:** Instala librerías de Python.

# %%
# %pip list

# %%
# %pip install faker

# %% [markdown]
# **%run:** Incluye o importa otro notebook dentro del notebook actual

# %%
# %run "/Workspace/Users/7425007221@untrm.edu.pe/course-certified-databricks-engineer-asociate/dea01-databricks-lakehouse-platform/2.1.run-notebook-hijo"

# %%
display(df)

# %%
imprimiendo_datos()

# %%
print(nombre)

# %%
# %run "./2.1.run-notebook-hijo"
