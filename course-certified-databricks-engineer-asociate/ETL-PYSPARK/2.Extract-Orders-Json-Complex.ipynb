# %% [markdown]
# # Vamos a extraer datos del archivo Order es un archivo complejo es decir anidado

# %%
df_orders=spark.read.format("json").load("/Volumes/gizmobox/landing/operational_data/orders/*.json")

# %%
display(df_orders.limit(10))

# %%
df_orders_text=spark.read.format("text").load("/Volumes/gizmobox/landing/operational_data/orders/*.json")

# %%
display(df_orders_text.limit(10))

# %%
    df_orders_text.writeTo("gizmobox.bronze.py_orders").createOrReplace()
