# %% [markdown]
# # Extraccion del archivo Customers json simples

# %%
# %fs ls "/Volumes/gizmobox/landing/operational_data"

# %%
df_customer_2024_10=spark.read.format("json").load("dbfs:/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json")

# %%
# Esta es otra manera de leer archivos
df_customer_2024_10_=spark.read.json("dbfs:/Volumes/gizmobox/landing/operational_data/customers/customers_2024_10.json")

# %%
display(df_customer_2024_10)

# %%
df_customers=spark.read.format("json").load("dbfs:/Volumes/gizmobox/landing/operational_data/customers/*.json")

# %%
display(df_customers.limit(10))

# %%
display(
    df_customers.select(
    "_metadata.file_path",
    '*'
).limit(5)
)

# %%
df_customers= df_customers.select(
    "_metadata.file_path",
    '*'
)

# %%
df_customers.write.format("delta").mode("overwrite").saveAsTable("gizmobox.bronze.py_customers")

# %%
display(spark.table("gizmobox.bronze.py_customers"))

# %%
# Con la API Write v2 se hace de la siguiente manera
df_customer.writeTo("gizmobox.bronze.py_customers").createOrReplace()
