# %% [markdown]
# # Extraccion de datos del archivo Membership de datos binarios en tes caso imagenes

# %%
df_membershit=spark.read.fomart("binaryFile").load("locationPath")

# %%
df_membershit.writeTo("gizmobox.bronze.py_orders").createOrReplace()
